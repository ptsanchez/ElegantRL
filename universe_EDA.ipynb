# %%
import pandas as pd
from IPython.display import display

# %%
universe = pd.read_parquet("/home/patricsanchez/ElegantRL/data/walk_forward/universe_2025.parquet")
pd.options.display.max_columns = None
display(universe)
# Out:
#                   timestamp  m5_mom_lrsi  m5_mom_tsi  m5_mom_squeeze_on  \
# 0       2025-01-02 09:30:00    -0.181558   -0.043934                1.0
# 1       2025-01-02 09:30:00     0.313329    0.101025               -1.0
# 2       2025-01-02 09:30:00    -0.214876   -0.068973               -1.0
# 3       2025-01-02 09:30:00    -0.113489   -0.072177               -1.0
# 4       2025-01-02 09:30:00     0.498923    0.214714               -1.0
# ...                     ...          ...         ...                ...
# 5477730 2025-07-25 16:00:00    -1.000000   -0.060618               -1.0
# 5477731 2025-07-25 16:00:00     0.908827    0.404608               -1.0
# 5477732 2025-07-25 16:00:00     0.913137    0.362119               -1.0
# 5477733 2025-07-25 16:00:00    -0.387273   -0.154959               -1.0
# 5477734 2025-07-25 16:00:00     1.000000    0.050521                1.0
#
#          m5_vol_rel_vol  m5_vol_rel_cum_vol  m5_ha_ha_color  \
# ...

# %%
pd.set_option('display.max_rows', None)
display(universe.describe().T)
# Out:
#                                     count                        mean  \
# timestamp                         5477735  2025-04-15 05:35:40.462528
# m5_mom_lrsi                     5477735.0                    0.037831
# m5_mom_tsi                      5477735.0                    0.010739
# m5_mom_squeeze_on               5477735.0                   -0.644986
# m5_vol_rel_vol                  5477735.0                   -0.380213
# m5_vol_rel_cum_vol              5477735.0                   -0.165441
# m5_ha_ha_color                  5477735.0                    0.023081
# m5_ha_ha_flat_bottom            5477735.0                   -0.475624
# m5_ha_ha_flat_top               5477735.0                   -0.508649
# m5_ha_ha_body_pct               5477735.0                    0.437752
# m5_ha_ha_wick_upper_pct         5477735.0                    0.283546
# m5_ha_ha_wick_lower_pct         5477735.0                    0.278702
# ...

# %%
len(universe['ticker'].unique())
# Out:
# 498

# %%
universe.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5477735 entries, 0 to 5477734
# Data columns (total 205 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    timestamp                       datetime64[us]
#  1    m5_mom_lrsi                     float64
#  2    m5_mom_tsi                      float64
#  3    m5_mom_squeeze_on               float32
#  4    m5_vol_rel_vol                  float32
#  5    m5_vol_rel_cum_vol              float32
#  6    m5_ha_ha_color                  float32
#  7    m5_ha_ha_flat_bottom            float32
#  8    m5_ha_ha_flat_top               float32
#  9    m5_ha_ha_body_pct               float32
#  10   m5_ha_ha_wick_upper_pct         float32
#  11   m5_ha_ha_wick_lower_pct         float32
#  12   m5_ha_ha_doji                   float32
#  13   m5_ha_ha_size_ratio             float32
#  14   m5_ha_ha_body_accel             float32
#  15   m5_ha_ha_trend_score_6          float32
# ...
