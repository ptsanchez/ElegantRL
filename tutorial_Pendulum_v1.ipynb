# %% [markdown]
# # **Pendulum-v1 Example in ElegantRL-HelloWorld**

# %% [markdown]
# # **Part 1: Install ElegantRL**

# %%
# install elegantrl library
#!pip install git+https://github.com/AI4Finance-LLC/ElegantRL.git

# %% [markdown]
# # **Part 2: Specify Environment and Agent**
#
# *   **agent**: chooses a agent (DRL algorithm) from a set of agents in the [directory](https://github.com/AI4Finance-Foundation/ElegantRL/tree/master/elegantrl/agents).
# *   **env**: creates an environment for your agent.

# %%
import gymnasium as gym

# %%
from elegantrl.train.config import Config
from elegantrl.agents.AgentSAC import AgentSAC

env = gym.make

env_args = {
    "id": "Pendulum-v1",
    "env_name": "Pendulum-v1",
    "num_envs": 1,
    "max_step": 1000,
    "state_dim": 3,
    "action_dim": 1,
    "if_discrete": False,
    "reward_scale": 2**-1,
    "gpu_id": 0, # if you have GPU
}
args = Config(AgentSAC, env_class=env, env_args=env_args)

# %% [markdown]
# # **Part 3: Specify hyper-parameters**
# A list of hyper-parameters is available [here](https://elegantrl.readthedocs.io/en/latest/api/config.html).

# %%
args.max_step = 1000
args.reward_scale = 2**-1  # RewardRange: -1800 < -200 < -50 < 0
args.gamma = 0.97
args.target_step = args.max_step
args.eval_times = 2**3
args.gpu_id = 0

# %% [markdown]
# # **Part 4: Train and Evaluate the Agent**

# %%
from elegantrl.train.run import train_agent

train_agent(args)
# Out:
# | train_agent_multiprocessing() with GPU_ID 0
# | Arguments Remove cwd: ./Pendulum-v1_SAC_0
# | Evaluator:
# | `step`: Number of samples, or total training steps, or running times of `env.step()`.
# | `time`: Time spent from the start of training to this moment.
# | `avgR`: Average value of cumulative rewards, which is the sum of rewards in an episode.
# | `stdR`: Standard dev of cumulative rewards, which is the sum of rewards in an episode.
# | `avgS`: Average of steps in an episode.
# | `objC`: Objective of Critic network. Or call it loss function of critic network.
# | `objA`: Objective of Actor network. It is the average Q value of the critic network.
# ################################################################################
# ID     Step    Time |    avgR   stdR   avgS  stdS |    expR   objC   objA   etc.
# 0  1.02e+03       2 |-1252.15  357.7    200     0 |   -2.52  11.13   0.04 0.03863252839073539
# 0  2.15e+04      31 |-1171.61   21.0    200     0 |   -2.65   1.41 -61.06 -61.06339923540751
# 0  4.20e+04     106 | -897.26  137.5    200     0 |   -2.17   0.53 -89.99 -89.99195986259275
# Process EvaluatorProc-3:
# Process Learner-1:
# Process Worker-2:
# Traceback (most recent call last):
#   File "/home/patrics/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/patrics/repos/ElegantRL/elegantrl/train/run.py", line 449, in run
#     actor, steps, exp_r, logging_tuple = self.pipe0.recv()
#   File "/home/patrics/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/patrics/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/patrics/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/patrics/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/patrics/repos/ElegantRL/elegantrl/train/run.py", line 298, in run
#     worker_id, buffer_items, last_state = self.recv_pipe.recv()
#   File "/home/patrics/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/patrics/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/patrics/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/patrics/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/patrics/repos/ElegantRL/elegantrl/train/run.py", line 412, in run
#     buffer_items = agent.explore_env(env, horizon_len)
#   File "/home/patrics/repos/ElegantRL/elegantrl/agents/AgentBase.py", line 74, in explore_env
#     return self._explore_one_env(env=env, horizon_len=horizon_len)
#   File "/home/patrics/repos/ElegantRL/elegantrl/agents/AgentBase.py", line 102, in _explore_one_env
#     action = self.explore_action(state)[0]
#   File "/home/patrics/repos/ElegantRL/elegantrl/agents/AgentSAC.py", line 34, in explore_action
#     return self.act.get_action(state)
#   File "/home/patrics/repos/ElegantRL/elegantrl/agents/AgentSAC.py", line 184, in get_action
#     dist = self.ActionDist(a_avg, a_std)
#   File "/home/patrics/repos/ElegantRL/.venv/lib/python3.10/site-packages/torch/distributions/normal.py", line 67, in __init__
#     super().__init__(batch_shape, validate_args=validate_args)
#   File "/home/patrics/repos/ElegantRL/.venv/lib/python3.10/site-packages/torch/distributions/distribution.py", line 77, in __init__
#     if not torch._is_all_true(valid):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from elegantrl.train.run import train_agent
# ----> 3 train_agent(args)
#
# File ~/repos/ElegantRL/elegantrl/train/run.py:31, in train_agent(args, if_single_process)
#      29 elif len(args.learner_gpu_ids) == 0:
#      30     print(f"| train_agent_multiprocessing() with GPU_ID {args.gpu_id}", flush=True)
# ---> 31     train_agent_multiprocessing(args)
#      32 elif len(args.learner_gpu_ids) != 0:
#      33     print(f"| train_agent_multiprocessing_multi_gpu() with GPU_ID {args.learner_gpu_ids}", flush=True)
#
# File ~/repos/ElegantRL/elegantrl/train/run.py:162, in train_agent_multiprocessing(args)
#     160 process_list = [learner, *workers, evaluator]
#     161 [process.start() for process in process_list]
# --> 162 [process.join() for process in process_list]
#
# File ~/repos/ElegantRL/elegantrl/train/run.py:162, in <listcomp>(.0)
#     160 process_list = [learner, *workers, evaluator]
#     161 [process.start() for process in process_list]
# --> 162 [process.join() for process in process_list]
#
# File ~/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/popen_fork.py:43, in Popen.wait(self, timeout)
#      41             return None
#      42     # This shouldn't block if wait() returned successfully.
# ---> 43     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44 return self.returncode
#
# File ~/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/popen_forkserver.py:65, in Popen.poll(self, flag)
#      63 from multiprocessing.connection import wait
#      64 timeout = 0 if flag == os.WNOHANG else None
# ---> 65 if not wait([self.sentinel], timeout):
#      66     return None
#      67 try:
#
# File ~/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     928     deadline = time.monotonic() + timeout
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#     933         return [key.fileobj for (key, events) in ready]
#
# File ~/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# Understanding the above results::
# *   **Step**: the total training steps.
# *  **MaxR**: the maximum reward.
# *   **avgR**: the average of the rewards.
# *   **stdR**: the standard deviation of the rewards.
# *   **objA**: the objective function value of Actor Network (Policy Network).
# *   **objC**: the objective function value (Q-value)  of Critic Network (Value Network).
